# %% [markdown]
# # **Stock Forecasting Prediction using LSTM**

# %% [markdown]
# ### **Problem Statement**
#
# Develop a predictive model using Long Short-Term Memory (LSTM) to forecast the closing stock prices based on historical stock market data, enabling insights for better financial decision-making.

# %% [markdown]
# ## **Overview**
#
# The dataset contains historical stock data with features such as Date, Open, High, Low, Close, Volume, Dividends, and Stock Splits. The primary objective is to utilize these features to build a time-series forecasting model for predicting the Close prices.
#
# Stock price prediction involves several challenges due to the noisy, volatile, and non-linear nature of the market. LSTMs, with their ability to capture sequential patterns and long-term dependencies, are an excellent choice for this task.

# %%
#import libraries
import tensorflow
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
matplotlib.rcParams["figure.figsize"] = (12, 6)
import joblib

# %%
#read the dat
df = pd.read_csv("/content/sample_data/Apple.csv")

df= df[8000:]
df.head()
# Out:
#                            Date       Open       High        Low      Close  \
# 8000  2012-08-28 00:00:00-04:00  20.422214  20.456102  20.291811  20.416769
# 8001  2012-08-29 00:00:00-04:00  20.430384  20.503603  20.350206  20.376528
# 8002  2012-08-30 00:00:00-04:00  20.290907  20.318440  20.055212  20.086073
# 8003  2012-08-31 00:00:00-04:00  20.188347  20.229192  19.885786  20.127533
# 8004  2012-09-04 00:00:00-04:00  20.143261  20.427062  20.105139  20.421919
#
#          Volume  Dividends  Stock Splits
# 8000  267416800        0.0           0.0
# 8001  202806800        0.0           0.0
# 8002  302699600        0.0           0.0
# 8003  338321200        0.0           0.0
# 8004  367892000        0.0           0.0

# %%
#make the Date column the index
df.index = pd.to_datetime(df["Date"],format = 'mixed', dayfirst=True, utc= True)

# %%
#plot the Closing stock trend

df["Close"].plot()
plt.title("Apple Stock Closing Price Trends")
plt.xticks(rotation=45);

# %% [markdown]
# **Early Years (1980-2000)**
#
# - The stock price remained relatively stable with minimal growth during this period.
#
# **Growth Phase (2000-2010)**
#
# - A gradual upward trend began, especially after the launch of iconic products such as the iPod (2001) and the iPhone (2007).
#
# **Exponential Growth (2010-2025)**
#
# -  (2020-2025) appears particularly steep, reflecting factors like increased adoption of technology, Apple’s dominance in premium markets, and potentially favorable market conditions.

# %%
#preprocess the data using Min Max so that the data ranges from 0 to 1 for the model to learn
df = df[["Close"]]
from sklearn.preprocessing import  MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df)
df =scaler.transform(df)

joblib.dump(scaler, 'scaling.pkl')
# Out:
# ['scaling.pkl']

# %%
#supervise  the model to predict the nth value from the provided data

window_size = 5

def df_to_X_y(df, window_size):

   X = []        # values
   y = []        # pred
   for i in range(len(df)-window_size):
      row = [[a] for a in df[i:i+window_size]]
      X.append(row)
      label = df[i+window_size]
      y.append(label)
   return np.array(X), np.array(y)

# %%
  # the size of the input values
X, y = df_to_X_y(df, window_size)
X.shape, y.shape
# Out:
# ((3108, 5, 1, 1), (3108, 1))

# %%
X[:5]
# Out:
# array([[[[0.03431156]],
#
#         [[0.03414869]],
#
#         [[0.03297315]],
#
#         [[0.03314095]],
#
#         [[0.0343324 ]]],
#
#
#        [[[0.03414869]],
#
#         [[0.03297315]],
#
#         [[0.03314095]],
#
#         [[0.0343324 ]],
#
#         [[0.03375193]]],
#
#
#        [[[0.03297315]],
#
#         [[0.03314095]],
#
#         [[0.0343324 ]],
#
#         [[0.03375193]],
#
#         [[0.03449159]]],
#
#
#        [[[0.03314095]],
#
#         [[0.0343324 ]],
#
#         [[0.03375193]],
#
#         [[0.03449159]],
#
#         [[0.0350022 ]]],
#
#
#        [[[0.0343324 ]],
#
#         [[0.03375193]],
#
#         [[0.03449159]],
#
#         [[0.0350022 ]],
#
#         [[0.03283477]]]])

# %% [markdown]
# # **Data Split**

# %%
X_train , y_train =X[:2000], y[:2000]
X_val, y_val = X[2000:2500], y[2000:2500]
X_test, y_test = X[2500:], y[2500:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2000, 5, 1, 1),
#  (2000, 1),
#  (500, 5, 1, 1),
#  (500, 1),
#  (608, 5, 1, 1),
#  (608, 1))

# %% [markdown]
# # **Import Model Dependencies**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import  RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
model1 = Sequential()
model1.add(InputLayer((window_size, 1)))
model1.add(LSTM(100))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 100)                 │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 41,617 (162.57 KB)
#  Trainable params: 41,617 (162.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#save the best model and compile
cp = ModelCheckpoint('model1/model1.keras', save_best_only = True)
model1.compile(loss = MeanSquaredError(), optimizer = Adam(learning_rate=0.001), metrics = [RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data =( X_val, y_val), epochs = 100, callbacks = [cp]);
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0055 - root_mean_squared_error: 0.0712 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2285e-05 - root_mean_squared_error: 0.0056 - val_loss: 9.5247e-04 - val_root_mean_squared_error: 0.0309
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3255e-05 - root_mean_squared_error: 0.0048 - val_loss: 6.9058e-04 - val_root_mean_squared_error: 0.0263
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4449e-05 - root_mean_squared_error: 0.0049 - val_loss: 7.1572e-04 - val_root_mean_squared_error: 0.0268
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3657e-05 - root_mean_squared_error: 0.0049 - val_loss: 6.6877e-04 - val_root_mean_squared_error: 0.0259
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.4961e-05 - root_mean_squared_error: 0.0050 - val_loss: 8.9242e-04 - val_root_mean_squared_error: 0.0299
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2711e-05 - root_mean_squared_error: 0.0047 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0353
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1383e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5739e-05 - root_mean_squared_error: 0.0051 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0345
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1976e-05 - root_mean_squared_error: 0.0047 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7015e-05 - root_mean_squared_error: 0.0052 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0397
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4968e-05 - root_mean_squared_error: 0.0050 - val_loss: 6.0501e-04 - val_root_mean_squared_error: 0.0246
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3712e-05 - root_mean_squared_error: 0.0049 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.9108e-05 - root_mean_squared_error: 0.0054 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0319
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7510e-05 - root_mean_squared_error: 0.0052 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1104e-05 - root_mean_squared_error: 0.0046 - val_loss: 5.7881e-04 - val_root_mean_squared_error: 0.0241
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6396e-05 - root_mean_squared_error: 0.0051 - val_loss: 5.9324e-04 - val_root_mean_squared_error: 0.0244
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7873e-05 - root_mean_squared_error: 0.0053 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2988e-05 - root_mean_squared_error: 0.0057 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0375
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4020e-05 - root_mean_squared_error: 0.0049 - val_loss: 7.6202e-04 - val_root_mean_squared_error: 0.0276
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4210e-05 - root_mean_squared_error: 0.0049 - val_loss: 5.3994e-04 - val_root_mean_squared_error: 0.0232
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2945e-05 - root_mean_squared_error: 0.0048 - val_loss: 7.8295e-04 - val_root_mean_squared_error: 0.0280
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4487e-05 - root_mean_squared_error: 0.0049 - val_loss: 6.4475e-04 - val_root_mean_squared_error: 0.0254
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4709e-05 - root_mean_squared_error: 0.0058 - val_loss: 6.1756e-04 - val_root_mean_squared_error: 0.0249
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4807e-05 - root_mean_squared_error: 0.0049 - val_loss: 4.9998e-04 - val_root_mean_squared_error: 0.0224
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4393e-05 - root_mean_squared_error: 0.0038 - val_loss: 2.0133e-04 - val_root_mean_squared_error: 0.0142
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5060e-05 - root_mean_squared_error: 0.0038 - val_loss: 2.4805e-04 - val_root_mean_squared_error: 0.0157
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4403e-05 - root_mean_squared_error: 0.0038 - val_loss: 1.6584e-04 - val_root_mean_squared_error: 0.0129
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2747e-05 - root_mean_squared_error: 0.0036 - val_loss: 2.5334e-04 - val_root_mean_squared_error: 0.0159
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6530e-05 - root_mean_squared_error: 0.0041 - val_loss: 1.3955e-04 - val_root_mean_squared_error: 0.0118
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4382e-05 - root_mean_squared_error: 0.0038 - val_loss: 1.5438e-04 - val_root_mean_squared_error: 0.0124
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.2644e-05 - root_mean_squared_error: 0.0035 - val_loss: 3.4485e-04 - val_root_mean_squared_error: 0.0186
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5540e-05 - root_mean_squared_error: 0.0039 - val_loss: 3.0727e-04 - val_root_mean_squared_error: 0.0175
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2405e-05 - root_mean_squared_error: 0.0035 - val_loss: 2.0819e-04 - val_root_mean_squared_error: 0.0144
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3160e-05 - root_mean_squared_error: 0.0036 - val_loss: 1.8246e-04 - val_root_mean_squared_error: 0.0135
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2375e-05 - root_mean_squared_error: 0.0035 - val_loss: 1.4986e-04 - val_root_mean_squared_error: 0.0122
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2556e-05 - root_mean_squared_error: 0.0035 - val_loss: 1.4633e-04 - val_root_mean_squared_error: 0.0121
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1907e-05 - root_mean_squared_error: 0.0034 - val_loss: 1.3848e-04 - val_root_mean_squared_error: 0.0118
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2174e-05 - root_mean_squared_error: 0.0035 - val_loss: 3.1534e-04 - val_root_mean_squared_error: 0.0178
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3854e-05 - root_mean_squared_error: 0.0037 - val_loss: 1.4970e-04 - val_root_mean_squared_error: 0.0122

# %%
#load the best model and make predictions
from tensorflow.keras.models import load_model
model1= load_model('model1/model1.keras')

# %% [markdown]
# ## **Predictions**

# %%
#predict on training data
train_predictions = model1.predict(X_train).flatten()
y_train = y_train.flatten()

#create a dataframe for train results
train_results = pd.DataFrame(data = {'Train Predictions': train_predictions, "Actuals" : y_train})
train_results.head(2)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#    Train Predictions   Actuals
# 0            0.03493  0.033752
# 1            0.03499  0.034492

# %%
#plot train results
plt.plot(train_results["Train Predictions"])
plt.plot(train_results['Actuals'])
plt.title("Training Data: Actual vs Predictions ");

# %%
#predict on validation data
val_predictions = model1.predict(X_val).flatten()
y_val = y_val.flatten()
val_results = pd.DataFrame(data = {"Val Predictions": val_predictions, "Actuals": y_val})
val_results.head(2)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#    Val Predictions   Actuals
# 0         0.406346  0.408246
# 1         0.407900  0.408818

# %%
#plot val results
plt.plot(val_results["Val Predictions"])
plt.plot(val_results['Actuals'])
plt.title("Validation Data: Actual vs Predictions ");

# %%
#predict on testing data
test_predictions = model1.predict(X_test).flatten()
y_test= y_test.flatten()
test_results = pd.DataFrame(data = {"Test Predictions": test_predictions, "Actuals": y_test})
test_results.head(2)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#    Test Predictions   Actuals
# 0          0.629929  0.639823
# 1          0.640062  0.644181

# %%
#plot the test results
plt.plot(test_results["Test Predictions"])
plt.plot(test_results['Actuals'])
plt.title("Testing Data: Actual vs Predictions ");

# %% [markdown]
# # **Validation**

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test_results['Actuals'], test_results['Test Predictions']))
print(rmse)
# Out:
# 0.012594578823369729

# %%
joblib.dump(model1, "model.keras")
# Out:
# ['model.keras']
